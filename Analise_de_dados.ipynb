# %% [markdown]
# <a href="https://colab.research.google.com/github/juan-jm90/Analise_grupo_de_estudos/blob/maria/Analise_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing depending libraries to read csv files
from pandas.io.parsers.readers import read_csv
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/My Drive/projeto analise dados/Estrangeiros_por_nacionalidade_2021_2.csv', encoding="latin-1", sep=";")
df2 = pd.read_csv('/content/drive/My Drive/projeto analise dados/Estrangeiros_por_nacionalidade_2022_1.csv', encoding="latin-1", sep=";")
df3 = pd.read_csv('/content/drive/My Drive/projeto analise dados/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_20190517.csv', encoding="utf-8", sep=";")
df4 = pd.read_csv('/content/drive/My Drive/projeto analise dados/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31012020.csv', encoding="utf-8", sep=";")
df5 = pd.read_csv('/content/drive/My Drive/projeto analise dados/VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31122020.csv', encoding="utf-8", sep=";")
df6 = pd.read_csv('/content/drive/My Drive/projeto analise dados/VW_MENSAL_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31032021.csv', encoding="utf-8", sep=";")

# %%
df1
# Out:
#                  NOMEDEP                     DE                  DISTR  \
# 0          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 1          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 2          ESTADUAL - SE                   LINS                   LINS
# 3          ESTADUAL - SE         CAMPINAS LESTE         CAMPINAS LESTE
# 4          ESTADUAL - SE         CAMPINAS LESTE         CAMPINAS LESTE
# ...                  ...                    ...                    ...
# 13416  ESTADUAL - OUTROS                JUNDIAI                JUNDIAI
# 13417  ESTADUAL - OUTROS                JUNDIAI                JUNDIAI
# 13418  ESTADUAL - OUTROS                LESTE 5             ARICANDUVA
# 13419  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
# 13420  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
#
#                          MUN  TIPOESC  COD_ESC  \
# 0      SAO BERNARDO DO CAMPO        8     9283
# ...

# %%
#importing csv to google colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1881f479-1809-470c-a67b-838e7279fe8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1881f479-1809-470c-a67b-838e7279fe8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Reading the files uploades with the read csv methods
df1 = pd.read_csv("Estrangeiros_por_nacionalidade_2021_2.csv", encoding='latin-1', sep=";")
df2 = pd.read_csv("Estrangeiros_por_nacionalidade_2022_1.csv", encoding='latin-1', sep=";")
df3 = pd.read_csv("VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_20190517.csv", encoding='utf-8', sep=";")
df4 = pd.read_csv("VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31012020.csv", encoding='utf-8', sep=";")
df5 = pd.read_csv("VW_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31122020.csv", encoding='utf-8', sep=";")
df6 = pd.read_csv("VW_MENSAL_ALUNOS_ESTRANGEIROS_POR_NACIONALIDADE_31032021.csv", encoding='utf-8', sep=";")

# %%
df1
# Out:
#                  NOMEDEP                     DE                  DISTR  \
# 0          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 1          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 2          ESTADUAL - SE                   LINS                   LINS
# 3          ESTADUAL - SE         CAMPINAS LESTE         CAMPINAS LESTE
# 4          ESTADUAL - SE         CAMPINAS LESTE         CAMPINAS LESTE
# ...                  ...                    ...                    ...
# 13416  ESTADUAL - OUTROS                JUNDIAI                JUNDIAI
# 13417  ESTADUAL - OUTROS                JUNDIAI                JUNDIAI
# 13418  ESTADUAL - OUTROS                LESTE 5             ARICANDUVA
# 13419  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
# 13420  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
#
#                          MUN  TIPOESC  COD_ESC  \
# 0      SAO BERNARDO DO CAMPO        8     9283
# ...

# %%
df2
# Out:
#                  NOMEDEP                     DE                  DISTR  \
# 0          ESTADUAL - SE            SANTO ANDRE            SANTO ANDRE
# 1          ESTADUAL - SE        SANTO ANASTACIO    PRESIDENTE EPITACIO
# 2          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 3          ESTADUAL - SE  SAO BERNARDO DO CAMPO  SAO BERNARDO DO CAMPO
# 4          ESTADUAL - SE                   LINS                   LINS
# ...                  ...                    ...                    ...
# 13825  ESTADUAL - OUTROS                JUNDIAI                JUNDIAI
# 13826  ESTADUAL - OUTROS                LESTE 5             ARICANDUVA
# 13827  ESTADUAL - OUTROS                LESTE 5             ARICANDUVA
# 13828  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
# 13829  ESTADUAL - OUTROS                LESTE 4            ARTUR ALVIM
#
#                          MUN  TIPOESC  COD_ESC  \
# 0                SANTO ANDRE        8   923370
# ...

# %%
df3
# Out:
#                 NOMEDEP              DE               DISTR  \
# 0     ESTADUAL - OUTROS  CAMPINAS LESTE      CAMPINAS LESTE
# 1     ESTADUAL - OUTROS    CENTRO OESTE      RAPOSO TAVARES
# 2     ESTADUAL - OUTROS      CENTRO SUL          BELA VISTA
# 3     ESTADUAL - OUTROS        SOROCABA            SOROCABA
# 4     ESTADUAL - OUTROS         TAUBATE            CACAPAVA
# ...                 ...             ...                 ...
# 9005            PRIVADA         TAUBATE            CACAPAVA
# 9006            PRIVADA         TAUBATE             TAUBATE
# 9007            PRIVADA      VOTORANTIM  ARACOIABA DA SERRA
# 9008            PRIVADA      VOTORANTIM      CAPELA DO ALTO
# 9009            PRIVADA      VOTORANTIM          VOTORANTIM
#
#                      MUN  TIPOESC  COD_ESC  \
# 0               CAMPINAS       27    45949
# 1              SAO PAULO       11   438820
# 2              SAO PAULO       11   299364
# 3               SOROCABA       11    16354
# ...

# %%
df4
# Out:
#                 NOMEDEP          DE              DISTR                MUN  \
# 0     ESTADUAL - OUTROS       APIAI              APIAI              APIAI
# 1     ESTADUAL - OUTROS     LIMEIRA            LIMEIRA            LIMEIRA
# 2     ESTADUAL - OUTROS     LIMEIRA            LIMEIRA            LIMEIRA
# 3     ESTADUAL - OUTROS    REGISTRO           REGISTRO           REGISTRO
# 4     ESTADUAL - OUTROS       SUL 1       VILA ANDRADE          SAO PAULO
# ...                 ...         ...                ...                ...
# 9195            PRIVADA  VOTORANTIM  SALTO DE PIRAPORA  SALTO DE PIRAPORA
# 9196            PRIVADA  VOTORANTIM  SALTO DE PIRAPORA  SALTO DE PIRAPORA
# 9197            PRIVADA  VOTORANTIM         VOTORANTIM         VOTORANTIM
# 9198            PRIVADA  VOTORANTIM         VOTORANTIM         VOTORANTIM
# 9199            PRIVADA  VOTORANTIM         VOTORANTIM         VOTORANTIM
#
#       TIPOESC  COD_ESC                              NOMESC  \
# ...

# %%
df5
# Out:
#                  NOMEDEP           DE         DISTR           MUN  TIPOESC  \
# 0      ESTADUAL - OUTROS   ADAMANTINA    ADAMANTINA    ADAMANTINA       11
# 1      ESTADUAL - OUTROS   ADAMANTINA    ADAMANTINA    ADAMANTINA       11
# 2      ESTADUAL - OUTROS   ADAMANTINA  OSVALDO CRUZ  OSVALDO CRUZ       11
# 3      ESTADUAL - OUTROS    AMERICANA     AMERICANA     AMERICANA       11
# 4      ESTADUAL - OUTROS    AMERICANA     AMERICANA     AMERICANA       11
# ...                  ...          ...           ...           ...      ...
# 12659            PRIVADA  VOTUPORANGA   VOTUPORANGA   VOTUPORANGA        0
# 12660            PRIVADA  VOTUPORANGA   VOTUPORANGA   VOTUPORANGA        0
# 12661            PRIVADA  VOTUPORANGA   VOTUPORANGA   VOTUPORANGA        0
# 12662            PRIVADA  VOTUPORANGA   VOTUPORANGA   VOTUPORANGA       40
# 12663            PRIVADA  VOTUPORANGA   VOTUPORANGA   VOTUPORANGA       57
#
# ...

# %%
df6
# Out:
#                  NOMEDEP           DE                  DISTR  \
# 0      ESTADUAL - OUTROS   ADAMANTINA             ADAMANTINA
# 1      ESTADUAL - OUTROS   ADAMANTINA           OSVALDO CRUZ
# 2      ESTADUAL - OUTROS    AMERICANA              AMERICANA
# 3      ESTADUAL - OUTROS    AMERICANA  SANTA BARBARA D'OESTE
# 4      ESTADUAL - OUTROS    AMERICANA  SANTA BARBARA D'OESTE
# ...                  ...          ...                    ...
# 12444            PRIVADA   VOTORANTIM             VOTORANTIM
# 12445            PRIVADA  VOTUPORANGA            VOTUPORANGA
# 12446            PRIVADA  VOTUPORANGA            VOTUPORANGA
# 12447            PRIVADA  VOTUPORANGA            VOTUPORANGA
# 12448            PRIVADA  VOTUPORANGA            VOTUPORANGA
#
#                          MUN  TIPOESC  COD_ESC  \
# 0                 ADAMANTINA       11    31100
# 1               OSVALDO CRUZ       11   915865
# 2                  AMERICANA       11    45962
# ...
